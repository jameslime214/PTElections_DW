# %%
import pandas as pd
import os

# %%
def generate_ddl_from_file(file_path):
    """
    Generate SQL DDL from a CSV or Excel file
    
    Args:
        file_path (str): Path to the input file (.csv, .xls, or .xlsx)
    
    Returns:
        str: SQL DDL statement
    """
    
    # Extract the file extension using os.path.splitext
    _, ext = os.path.splitext(file_path)
    file_extension = ext.lower()[1:]  # Remove the leading dot

    # Check if the file extension is valid
    if file_extension == 'csv':
        df = pd.read_csv(file_path)
    elif file_extension in ['xls', 'xlsx']:
        df = pd.read_excel(file_path)
    else:
        raise ValueError("Unsupported file format. Please use .csv, .xls, or .xlsx files")

    dtype_mapping = {
        'object': 'TEXT',
        'int64': 'INTEGER',
        'float64': 'NUMERIC',
        'datetime64[ns]': 'TIMESTAMP',
        'bool': 'BOOLEAN'
    }
    
    # Use os.path.basename and os.path.splitext to extract the table name
    table_name = os.path.splitext(os.path.basename(file_path))[0].lower()
    columns = []
    for column, dtype in df.dtypes.items():
        sql_type = dtype_mapping.get(str(dtype), 'TEXT')
        columns.append(f'    "{column}" {sql_type}')
    
    # Data table creation DDL
    ddl = f"CREATE TABLE IF NOT EXISTS {table_name} (\n"
    ddl += ",\n".join(columns)
    ddl += "\n);"
    
    # Data insertion DDL / Extraction step of the ETL process
    columns_list = ", ".join([f'"{col}"' for col in df.columns])
    insert_statements = []
    for index, row in df.iterrows():
        values = []
        for col in df.columns:
            if pd.isna(row[col]):
                values.append('NULL')
            elif isinstance(row[col], (int, float)):
                values.append(str(row[col]))
            elif isinstance(row[col], bool):
                values.append('TRUE' if row[col] else 'FALSE')
            elif isinstance(row[col], str):
                values.append(f"'{row[col].replace('\'', '\'\'')}'")
            else:
                values.append(str(row[col]))
        values_str = ", ".join(values)
        insert_statements.append(f"INSERT INTO {table_name} ({columns_list}) VALUES ({values_str});")
    ddl += "\n\n" + "\n".join(insert_statements)
    ddl += "\n"

    return df, ddl

# %%
# Directory containing the data files
data_dir = './Data_Selected'
output_dir = './sql_scripts/ddl-dml'

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through every file in the data directory
for file_name in os.listdir(data_dir):
    file_path = os.path.join(data_dir, file_name)
    
    # Process the file using your SQL DDL function
    try:
        _, sql_script = generate_ddl_from_file(file_path)
    except Exception as e:
        print(f"Error processing {file_name}: {e}")
        continue
    
    # Build the output file name based on the original file's name
    base_name, _ = os.path.splitext(file_name)
    output_file = os.path.join(output_dir, base_name + '.sql')
    
    # Write the generated SQL script to the output file
    with open(output_file, 'w') as f:
        f.write(sql_script)
    
    print(f"SQL script for {file_name} saved to {output_file}")
# Out:
# Error processing Ar76c.txt: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing Ar76f.txt: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR79C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR79F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR80C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR80F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR83C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR83F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR85C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR85F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR87C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR87F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR91C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR91F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR95C.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# Error processing AR95F.TXT: Unsupported file format. Please use .csv, .xls, or .xlsx files
# SQL script for ar_1975_constituinte.xls saved to ./sql_scripts/ddl-dml\ar_1975_constituinte.sql
# SQL script for ar_1976.xls saved to ./sql_scripts/ddl-dml\ar_1976.sql
# SQL script for ar_1979_intercalar.xls saved to ./sql_scripts/ddl-dml\ar_1979_intercalar.sql
# SQL script for ar_1980.xls saved to ./sql_scripts/ddl-dml\ar_1980.sql
# SQL script for ar_1983.xls saved to ./sql_scripts/ddl-dml\ar_1983.sql
# SQL script for ar_1985.xls saved to ./sql_scripts/ddl-dml\ar_1985.sql
# SQL script for ar_1987.xls saved to ./sql_scripts/ddl-dml\ar_1987.sql
# SQL script for ar_1991.xls saved to ./sql_scripts/ddl-dml\ar_1991.sql
# SQL script for ar_1995.xls saved to ./sql_scripts/ddl-dml\ar_1995.sql
# SQL script for ar_1999.xls saved to ./sql_scripts/ddl-dml\ar_1999.sql
# SQL script for ar_2002.xls saved to ./sql_scripts/ddl-dml\ar_2002.sql
# SQL script for ar_2005.xls saved to ./sql_scripts/ddl-dml\ar_2005.sql
# SQL script for ar_2009.xls saved to ./sql_scripts/ddl-dml\ar_2009.sql
# SQL script for ar_2011.xls saved to ./sql_scripts/ddl-dml\ar_2011.sql
# Error processing diff_format: Unsupported file format. Please use .csv, .xls, or .xlsx files

# %% [markdown]
# ### cells below are explicitly for testing / debugging purposes

# %%
_, test_sql_ddl = generate_ddl_from_file('../OriginalMAIdata/ar_1999.xls')
print(test_sql_ddl)
ddl_path = './sql_scripts/ddl_script.sql'
with open(ddl_path, 'w') as f:
    f.write(test_sql_ddl)
# Out:
# CREATE TABLE IF NOT EXISTS ar_1999 (
#     "CODIGO" INTEGER,
#     "DIST_CONC_FREG" TEXT,
#     "T_ELEI" TEXT,
#     "D_ELEI" TEXT,
#     "SIGLA" TEXT,
#     "T_DADOS" TEXT,
#     "VOTOS" INTEGER,
#     "P_VOTOS" NUMERIC,
#     "MANDATOS" INTEGER
# );
#
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'CDS/PP', 'O', 49196, 13.579999923706055, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'B.E.', 'O', 4677, 1.2899999618530273, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'MPT', 'O', 842, 0.23000000417232513, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PH', 'O', 971, 0.27000001072883606, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PCP/PEV', 'O', 12787, 3.5299999713897705, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 1520, 0.41999998688697815, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PPD/PSD', 'O', 138717, 38.279998779296875, 6);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PPM', 'O', 1142, 0.3199999928474426, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PS', 'O', 145577, 40.18000030517578, 7);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (10000, 'AVEIRO', 'ar', '10/10/1999', 'PSN', 'O', 660, 0.18000000715255737, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'B.E.', 'O', 1314, 1.5499999523162842, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'CDS/PP', 'O', 3313, 3.9000000953674316, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'MPT', 'O', 277, 0.33000001311302185, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'PCP/PEV', 'O', 24080, 28.31999969482422, 1);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 1664, 1.9600000381469727, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'PPD/PSD', 'O', 12310, 14.479999542236328, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'PPM', 'O', 395, 0.46000000834465027, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'PS', 'O', 39729, 46.72999954223633, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (20000, 'BEJA', 'ar', '10/10/1999', 'PSN', 'O', 210, 0.25, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'B.E.', 'O', 5164, 1.1699999570846558, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'CDS/PP', 'O', 38973, 8.859999656677246, 1);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'MPT', 'O', 969, 0.2199999988079071, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PCP/PEV', 'O', 23828, 5.420000076293945, 1);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 2963, 0.6700000166893005, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PH', 'O', 863, 0.20000000298023224, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'POUS', 'O', 827, 0.1899999976158142, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PPD/PSD', 'O', 161616, 36.7400016784668, 7);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PPM', 'O', 1436, 0.33000001311302185, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PS', 'O', 194979, 44.31999969482422, 8);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (30000, 'BRAGA', 'ar', '10/10/1999', 'PSN', 'O', 1750, 0.4000000059604645, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'B.E.', 'O', 695, 0.8399999737739563, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'CDS/PP', 'O', 7131, 8.65999984741211, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'MPT', 'O', 314, 0.3799999952316284, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'PCP/PEV', 'O', 2160, 2.619999885559082, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 537, 0.6499999761581421, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'PPD/PSD', 'O', 37130, 45.099998474121094, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (40000, 'BRAGANÇA', 'ar', '10/10/1999', 'PS', 'O', 32715, 39.7400016784668, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES
 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (180000, 'VISEU', 'ar', '10/10/1999', 'PS', 'O', 77726, 38.13999938964844, 4);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (180000, 'VISEU', 'ar', '10/10/1999', 'PSN', 'O', 643, 0.3199999928474426, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'B.E.', 'O', 993, 1.059999942779541, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'B.E.', 'O', 993, 1.059999942779541, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'CDS/PP', 'O', 5219, 5.570000171661377, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'CDS/PP', 'O', 5219, 5.570000171661377, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'MPT', 'O', 176, 0.1899999976158142, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'MPT', 'O', 176, 0.1899999976158142, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'PCP/PEV', 'O', 1620, 1.7300000190734863, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'PCP/PEV', 'O', 1620, 1.7300000190734863, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 331, 0.3499999940395355, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 331, 0.3499999940395355, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'PDA', 'O', 438, 0.4699999988079071, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'PDA', 'O', 438, 0.4699999988079071, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'PPD/PSD', 'O', 33524, 35.77000045776367, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'PPD/PSD', 'O', 33524, 35.77000045776367, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'São Jorge', 'ar', '10/10/1999', 'PS', 'O', 49954, 53.29999923706055, 3);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (190000, 'AÇORES - Grupo Central', 'ar', '10/10/1999', 'PS', 'O', 49954, 53.29999923706055, 3);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'PCP/PEV', 'O', 3428, 2.819999933242798, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'B.E.', 'O', 1481, 1.2200000286102295, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'CDS/PP', 'O', 13209, 10.859999656677246, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'MPT', 'O', 487, 0.4000000059604645, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 651, 0.5400000214576721, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'PPD/PSD', 'O', 56205, 46.20000076293945, 3);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'PS', 'O', 42637, 35.04999923706055, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (220000, 'MADEIRA', 'ar', '10/10/1999', 'PSN', 'O', 571, 0.4699999988079071, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'B.E.', 'O', 132333, 2.440000057220459, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'CDS/PP', 'O', 451643, 8.34000015258789, 15);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'MPT', 'O', 19938, 0.3700000047683716, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PH', 'O', 7346, 0.14000000059604645, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PCP/PEV', 'O', 487058, 8.989999771118164, 17);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 40006, 0.7400000095367432, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PDA', 'O', 438, 0.009999999776482582, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'POUS', 'O', 4104, 0.07999999821186066, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PPD/PSD', 'O', 1750158, 32.31999969482422, 81);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PPM', 'O', 16522, 0.3100000023841858, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PS', 'O', 2385922, 44.060001373291016, 115);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (230000, 'PORTUGAL', 'ar', '10/10/1999', 'PSN', 'O', 11488, 0.20999999344348907, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'B.E.', 'O', 145, 0.5600000023841858, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'CDS/PP', 'O', 829, 3.2200000286102295, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'MPT', 'O', 276, 1.0700000524520874, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PCP/PEV', 'O', 1351, 5.25, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 219, 0.8500000238418579, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PH', 'O', 20, 0.07999999821186066, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'POUS', 'O', 33, 0.12999999523162842, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PPD/PSD', 'O', 6353, 24.670000076293945, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PPM', 'O', 74, 0.28999999165534973, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PS', 'O', 14277, 55.439998626708984, 2);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750040, 'EUROPA', 'ar', '10/10/1999', 'PSN', 'O', 25, 0.10000000149011612, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'B.E.', 'O', 63, 0.3700000047683716, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'CDS/PP', 'O', 593, 3.4600000381469727, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'MPT', 'O', 69, 0.4000000059604645, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'PCP/PEV', 'O', 287, 1.6799999475479126, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'PCTP/MRPP', 'O', 49, 0.28999999165534973, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'PPD/PSD', 'O', 8470, 49.459999084472656, 1);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'PPM', 'O', 45, 0.25999999046325684, 0);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'PS', 'O', 6818, 39.81999969482422, 1);
# INSERT INTO ar_1999 ("CODIGO", "DIST_CONC_FREG", "T_ELEI", "D_ELEI", "SIGLA", "T_DADOS", "VOTOS", "P_VOTOS", "MANDATOS") VALUES (750050, 'FORA DA EUROPA', 'ar', '10/10/1999', 'PSN', 'O', 83, 0.47999998927116394, 0);
